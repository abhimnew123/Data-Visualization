# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline
import seaborn as sns
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Univariate Plotting

# %%
df_mcd = pd.read_excel('https://github.com/insaid2018/Term-1/raw/master/Data/Casestudy/mcdonalds_india_menu.xlsx')
df_mcd.head()
# Out:
#     Category                  Item  Serve_Size  Energy  Protein  Total_Fat  \
# 0  Breakfast     Egg & Cheese Muﬃn         112     290       14         13
# 1  Breakfast        Sausage McMuﬀm         112     273       16         11
# 2  Breakfast  Sausage & Egg McMuﬀm         157     355       22         17
# 3  Breakfast            Veg McMuﬀm         119     299       10         12
# 4  Breakfast      Veg Supreme Muﬃn         139     299        7         13
#
#    Saturated_Fat  Trans_Fat  Cholestrol  Carbohydrates  Sugars  Dietary_Fibre  \
# 0            7.0        0.2         244             28       2              2
# 1            5.7        0.2          50             28       2              2
# 2            7.9        0.2         277             29       2              2
# 3            7.2        0.2          21             38       3              3
# 4            5.2        0.2          11             39       4              4
#
#   Sodium High_Or_Low_Sugar
# 0    620         Low Sugar
# 1    950         Low Sugar
# 2   1020         Low Sugar
# 3   1000         Low Sugar
# 4    960         Low Sugar

# %%
df_store = pd.read_excel('https://github.com/insaid2018/Term-1/raw/master/Data/Casestudy/mcdonalds_store_data.xlsx')
df_store.head()
# Out:
#         Brand      Store ID     Store Name  \
# 0  McDonald's  23149-228271  Banjara Hills
# 1  McDonald's  23191-228548     Kukatpally
# 2  McDonald's  23193-228546       Madhapur
# 3  McDonald's  23180-228545  Jubilee Hills
# 4  McDonald's  24457-238129   Hi-Tech City
#
#                                       Street Address       City State  \
# 0  Lower Ground Floor, GVK One, Road Number 1, Ba...  Hyderabad    AP
# 1  Upper Ground Floor, Forum Sujana Mall, Kukatpally  Hyderabad    AP
# 2         Lower Ground Floor, Inorbit Mall, Madhapur  Hyderabad    AP
# 3  Ground Floor, Road No. 92, Near Apollo hospita...  Hyderabad    AP
# 4  Upper Ground Floor, Phoenix tower A, Opposite ...  Hyderabad    AP
#
#    Postcode  Longitude  Latitude       Revenue       Profits  Selling Price  \
# 0    500034      78.45     17.42  2.117344e+06  1.715839e+05   1.655165e+06
# 1    500072      78.39     17.48  1.058504e+06  5.464539e+04   8.959440e+05
# 2    500081      78.39     17.43  4.505020e+06  6.638673e+05   2.864311e+06
# 3    500033      78.42     17.42  3.405530e+06  3.978350e+05   2.394072e+06
# 4    500084      78.38     17.45  7.332713e+06  1.656524e+06   3.395053e+06
#
#      Cost Price  Gross Profit Margin  Number of Employees     Customers  \
# 0  9.074330e+05        747732.417746            34.311197   3979.583117
# 1  4.536446e+05        442299.411904            25.487533   1156.010620
# 2  1.930723e+06        933588.360542            54.208502  10346.720786
# 3  1.459513e+06        934559.026524            45.046083   7414.746544
# 4  3.142591e+06        252461.315787            77.772607  17887.234107
#
#         Most Prefered Meal     Most Selling Item
# 0        McAloo Tikki Meal          McEgg Burger
# 1  Chatpata Naan Aloo Meal  Chicken Maharaja Mac
# 2       Chicken Kebab Meal             McChicken
# 3            McVeggie Meal          Filet-O-Fish
# 4           McChicken Meal       Chicken McGrill

# %% [markdown]
# BAR CHART

# %%
df_mcd['Category'].value_counts().plot.bar(figsize=(15,7), colormap='Dark2', fontsize=13, yticks=np.arange(0, 19, 2))

# %%
df_mcd['Category'].value_counts().plot.bar(figsize=(15,7), colormap='Dark2', fontsize=13, yticks=np.arange(0, 19, 2))
plt.xlabel('Category')
plt.ylabel('Number of Items')
plt.title('Bar Chart showing the Number of Items in each Category value')
plt.title('Bar Chart showing the Number of Items in each Category value')
# Out:
# Text(0.5, 1.0, 'Bar Chart showing the Number of Items in each Category value')

# %%
(df_mcd['Category'].value_counts() / len(df_mcd)).plot(kind='bar', figsize=(16,7), colormap='magma', fontsize=13)

plt.xlabel('Category')
plt.ylabel('Proportion of Items')
plt.title('Bar Chart showing the proportion of Items in each Category value')
# Out:
# Text(0.5, 1.0, 'Bar Chart showing the proportion of Items in each Category value')

# %%
df_mcd[['Energy']].plot(kind='line', figsize=(15,7), color='blue', fontsize=13, linestyle='-.')

plt.xlabel('Index')
plt.ylabel('Energy (kcal)')
plt.title('Line chart showing the variation of energy across different items')
# Out:
# Text(0.5, 1.0, 'Line chart showing the variation of energy across different items')

# %%
df_mcd.iloc[:28]['Category'].value_counts()
# Out:
# Sandwiches and Wraps    11
# Breakfast                8
# Snacks                   4
# Nuggets                  3
# Chicken Wings            2
# Name: Category, dtype: int64

# %% [markdown]
# AREA CHART

# %%
df_mcd['Total_Fat'].plot(kind='area', figsize=(15,7), color='violet', fontsize=13)
                                                                    
plt.xlabel('Index')
plt.ylabel('Total_Fat')
plt.title('Area chart showing the variation of Total Fat across different items')
# Out:
# Text(0.5, 1.0, 'Area chart showing the variation of Total Fat across different items')

# %%
print(df_mcd.iloc[15:28]['Category'].value_counts())

print('\n\nThe item with highest Total Fat belongs to', df_mcd.iloc[df_mcd.iloc[15:28]['Total_Fat'].argmax()]['Category'])
# Out:
# Sandwiches and Wraps    4
# Snacks                  4
# Nuggets                 3
# Chicken Wings           2
# Name: Category, dtype: int64
#
#
# The item with highest Total Fat belongs to Sandwiches and Wraps

# %%
df_mcd['Serve_Size'].head(10)
# Out:
# 0    112
# 1    112
# 2    157
# 3    119
# 4    139
# 5    142
# 6     64
# 7    115
# 8    246
# 9    173
# Name: Serve_Size, dtype: int64

# %%
bins = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
df_mcd['Serve_Size'].plot(kind='hist', bins = bins, figsize=(15, 7), color='brown', yticks=np.arange(0, 22, 3), xticks=bins)

plt.xlabel('Serve_Size')
plt.ylabel('Frequency')
plt.title('Histogram showing the distribution of Serve Size values')
# Out:
# Text(0.5, 1.0, 'Histogram showing the distribution of Serve Size values')

# %% [markdown]
# KERNEL Density Plot

# %%
bins = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
df_mcd['Serve_Size'].plot(kind='hist', bins = bins, figsize=(15, 7), color='brown', yticks=np.arange(0, 22, 3), xticks=bins)

plt.xlabel('Serve_Size')
plt.ylabel('Frequency')
plt.title('Histogram showing the distribution of Serve Size values')
# Out:
# Text(0.5, 1.0, 'Histogram showing the distribution of Serve Size values')

# %%
space = np.ones(11)/10
df_mcd['Category'].value_counts().plot(kind='pie', explode=space, fontsize=14, autopct='%3.1f%%', wedgeprops=dict(width=0.15), 
                                       shadow=True, startangle=160, figsize=(10,10), cmap='inferno', legend=True)

plt.ylabel('Category')
plt.title('Donut Plot showing the proportion of each Category value')
# Out:
# Text(0.5, 1.0, 'Donut Plot showing the proportion of each Category value')

# %% [markdown]
# Bivarite Plotting

# %%
df_mcd.plot(kind='scatter', x='Carbohydrates', y='Energy', figsize=(10, 6), color='purple', grid=False)

plt.title('Scatter plot showing the variation of Energy with Carbohydrates present in each item')
# Out:
# Text(0.5, 1.0, 'Scatter plot showing the variation of Energy with Carbohydrates present in each item')

# %%
plt.figure(figsize=(12,7))
sns.regplot(data=df_mcd, x='Carbohydrates', y='Energy', color='brown')
plt.figure(figsize=(12,7))
sns.regplot(data=df_mcd, x='Carbohydrates', y='Energy', color='brown')

plt.title('Regplot showing the variation of Energy with Carbohydrates present in each item')
plt.title('Regplot showing the variation of Energy with Carbohydrates present in each item')
# Out:
# Text(0.5, 1.0, 'Regplot showing the variation of Energy with Carbohydrates present in each item')

# %%
plt.figure(figsize=(12,7))
sns.regplot(data=df_mcd, x='Carbohydrates', y='Energy', color='brown')

plt.title('Regplot showing the variation of Energy with Carbohydrates present in each item')
# Out:
# Text(0.5, 1.0, 'Regplot showing the variation of Energy with Carbohydrates present in each item')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline
import seaborn as sns
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)
import warnings
warnings.filterwarnings('ignore')

# %%
df_mcd = pd.read_excel('https://github.com/insaid2018/Term-1/raw/master/Data/Casestudy/mcdonalds_india_menu.xlsx')
df_mcd.head()
# Out:
#     Category                  Item  Serve_Size  Energy  Protein  Total_Fat  \
# 0  Breakfast     Egg & Cheese Muﬃn         112     290       14         13
# 1  Breakfast        Sausage McMuﬀm         112     273       16         11
# 2  Breakfast  Sausage & Egg McMuﬀm         157     355       22         17
# 3  Breakfast            Veg McMuﬀm         119     299       10         12
# 4  Breakfast      Veg Supreme Muﬃn         139     299        7         13
#
#    Saturated_Fat  Trans_Fat  Cholestrol  Carbohydrates  Sugars  Dietary_Fibre  \
# 0            7.0        0.2         244             28       2              2
# 1            5.7        0.2          50             28       2              2
# 2            7.9        0.2         277             29       2              2
# 3            7.2        0.2          21             38       3              3
# 4            5.2        0.2          11             39       4              4
#
#   Sodium High_Or_Low_Sugar
# 0    620         Low Sugar
# 1    950         Low Sugar
# 2   1020         Low Sugar
# 3   1000         Low Sugar
# 4    960         Low Sugar

# %%
df_store = pd.read_excel('https://github.com/insaid2018/Term-1/raw/master/Data/Casestudy/mcdonalds_store_data.xlsx')
df_store.head()
# Out:
#         Brand      Store ID     Store Name  \
# 0  McDonald's  23149-228271  Banjara Hills
# 1  McDonald's  23191-228548     Kukatpally
# 2  McDonald's  23193-228546       Madhapur
# 3  McDonald's  23180-228545  Jubilee Hills
# 4  McDonald's  24457-238129   Hi-Tech City
#
#                                       Street Address       City State  \
# 0  Lower Ground Floor, GVK One, Road Number 1, Ba...  Hyderabad    AP
# 1  Upper Ground Floor, Forum Sujana Mall, Kukatpally  Hyderabad    AP
# 2         Lower Ground Floor, Inorbit Mall, Madhapur  Hyderabad    AP
# 3  Ground Floor, Road No. 92, Near Apollo hospita...  Hyderabad    AP
# 4  Upper Ground Floor, Phoenix tower A, Opposite ...  Hyderabad    AP
#
#    Postcode  Longitude  Latitude       Revenue       Profits  Selling Price  \
# 0    500034      78.45     17.42  2.117344e+06  1.715839e+05   1.655165e+06
# 1    500072      78.39     17.48  1.058504e+06  5.464539e+04   8.959440e+05
# 2    500081      78.39     17.43  4.505020e+06  6.638673e+05   2.864311e+06
# 3    500033      78.42     17.42  3.405530e+06  3.978350e+05   2.394072e+06
# 4    500084      78.38     17.45  7.332713e+06  1.656524e+06   3.395053e+06
#
#      Cost Price  Gross Profit Margin  Number of Employees     Customers  \
# 0  9.074330e+05        747732.417746            34.311197   3979.583117
# 1  4.536446e+05        442299.411904            25.487533   1156.010620
# 2  1.930723e+06        933588.360542            54.208502  10346.720786
# 3  1.459513e+06        934559.026524            45.046083   7414.746544
# 4  3.142591e+06        252461.315787            77.772607  17887.234107
#
#         Most Prefered Meal     Most Selling Item
# 0        McAloo Tikki Meal          McEgg Burger
# 1  Chatpata Naan Aloo Meal  Chicken Maharaja Mac
# 2       Chicken Kebab Meal             McChicken
# 3            McVeggie Meal          Filet-O-Fish
# 4           McChicken Meal       Chicken McGrill

# %%
df_mcd.groupby(['Category'])['Total_Fat'].mean().plot(kind='bar', figsize=(15, 7), color='orange')
df_mcd.groupby(['Category'])['Saturated_Fat'].mean().plot(kind='bar', figsize=(15, 7), color='grey')
df_mcd.groupby(['Category'])['Trans_Fat'].mean().plot(kind='bar', figsize=(15, 7), color='red', fontsize=13)

plt.xlabel('Category')
plt.ylabel('Fat Content')
plt.title('Stacked Bar Chart showing the Fat content of each Category')
plt.legend(labels=('Total_Fat', 'Saturated_Fat', 'Trans_Fat'))

# %%
df_mcd.plot(kind='hexbin', x='Serve_Size', y='Energy', figsize=(15, 7), gridsize=25, fontsize=13, colormap='Reds')

plt.title('Hexplot showing the variation of Energy with Serve_Size of each item')
# Out:
# Text(0.5, 1.0, 'Hexplot showing the variation of Energy with Serve_Size of each item')

# %%
df_store.groupby(['Customers'])['Revenue'].mean().plot(kind='area', figsize=(15, 7), color='#347593')
df_store.groupby(['Customers'])['Profits'].mean().plot(kind='area', figsize=(15, 7), color='#363552', fontsize=13)


plt.xlabel('Customers')
plt.ylabel('Value')
plt.title('Stacked Area Chart showing the Revenue and Profit in each state')
plt.legend(labels=('Revenue', 'Profits'))

# %%
df_mcd.groupby(['Serve_Size'])['Cholestrol'].mean().plot(kind='line', figsize=(15, 7), color='green')
df_mcd.groupby(['Serve_Size'])['Total_Fat'].mean().plot(kind='line', figsize=(15, 7), color='red')

plt.ylabel('Value')
plt.title('Bivariate Linear Chart showing the variation of Cholestrol and Total_Fat with Serve_Size')
plt.legend(['Cholestrol (in mg)', 'Total_Fat (in g)'])

# %%
sns.pairplot(data=df_mcd[['Energy', 'Total_Fat', 'Sugars', 'Carbohydrates', 'Protein']], size=2.5, diag_kind='kde')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df_mcd, x='Sugars', y='Energy', hue='Category')

plt.xlabel('Sugars')
plt.ylabel('Energy')
plt.title('Scatter plot showing the variation of Energy with Sugars present in each item with a hue based on Category')
plt.grid(False)
plt.legend(fontsize=12)

# %%
plt.figure(figsize=(12,7))
sns.boxplot(data=df_store, x='State', y='Revenue', palette='rainbow')

plt.title('Revenue vs State')
# Out:
# Text(0.5, 1.0, 'Revenue vs State')

# %%
corr_mat = df_mcd.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_mat, annot=True, cmap='viridis')

# %%
df_mcd = pd.read_excel('https://github.com/insaid2018/Term-1/raw/master/Data/Casestudy/mcdonalds_india_menu.xlsx')
df_mcd.head()
# Out:
#     Category                  Item  Serve_Size  Energy  Protein  Total_Fat  \
# 0  Breakfast     Egg & Cheese Muﬃn         112     290       14         13
# 1  Breakfast        Sausage McMuﬀm         112     273       16         11
# 2  Breakfast  Sausage & Egg McMuﬀm         157     355       22         17
# 3  Breakfast            Veg McMuﬀm         119     299       10         12
# 4  Breakfast      Veg Supreme Muﬃn         139     299        7         13
#
#    Saturated_Fat  Trans_Fat  Cholestrol  Carbohydrates  Sugars  Dietary_Fibre  \
# 0            7.0        0.2         244             28       2              2
# 1            5.7        0.2          50             28       2              2
# 2            7.9        0.2         277             29       2              2
# 3            7.2        0.2          21             38       3              3
# 4            5.2        0.2          11             39       4              4
#
#   Sodium High_Or_Low_Sugar
# 0    620         Low Sugar
# 1    950         Low Sugar
# 2   1020         Low Sugar
# 3   1000         Low Sugar
# 4    960         Low Sugar

# %%
df_mcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 14 columns):
# Category             83 non-null object
# Item                 83 non-null object
# Serve_Size           83 non-null int64
# Energy               83 non-null int64
# Protein              83 non-null int64
# Total_Fat            83 non-null int64
# Saturated_Fat        83 non-null float64
# Trans_Fat            83 non-null float64
# Cholestrol           83 non-null int64
# Carbohydrates        83 non-null int64
# Sugars               83 non-null int64
# Dietary_Fibre        83 non-null int64
# Sodium               83 non-null object
# High_Or_Low_Sugar    83 non-null object
# dtypes: float64(2), int64(8), object(4)
# memory usage: 9.2+ KB

# %%
df_menu = pd.read_excel('https://github.com/insaid2018/Term-1/raw/master/Data/Casestudy/mcdonalds_india_menu.xlsx')
df_menu.head()
# Out:
#     Category                  Item  Serve_Size  Energy  Protein  Total_Fat  \
# 0  Breakfast     Egg & Cheese Muﬃn         112     290       14         13
# 1  Breakfast        Sausage McMuﬀm         112     273       16         11
# 2  Breakfast  Sausage & Egg McMuﬀm         157     355       22         17
# 3  Breakfast            Veg McMuﬀm         119     299       10         12
# 4  Breakfast      Veg Supreme Muﬃn         139     299        7         13
#
#    Saturated_Fat  Trans_Fat  Cholestrol  Carbohydrates  Sugars  Dietary_Fibre  \
# 0            7.0        0.2         244             28       2              2
# 1            5.7        0.2          50             28       2              2
# 2            7.9        0.2         277             29       2              2
# 3            7.2        0.2          21             38       3              3
# 4            5.2        0.2          11             39       4              4
#
#   Sodium High_Or_Low_Sugar
# 0    620         Low Sugar
# 1    950         Low Sugar
# 2   1020         Low Sugar
# 3   1000         Low Sugar
# 4    960         Low Sugar

# %%
df_menu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 14 columns):
# Category             83 non-null object
# Item                 83 non-null object
# Serve_Size           83 non-null int64
# Energy               83 non-null int64
# Protein              83 non-null int64
# Total_Fat            83 non-null int64
# Saturated_Fat        83 non-null float64
# Trans_Fat            83 non-null float64
# Cholestrol           83 non-null int64
# Carbohydrates        83 non-null int64
# Sugars               83 non-null int64
# Dietary_Fibre        83 non-null int64
# Sodium               83 non-null object
# High_Or_Low_Sugar    83 non-null object
# dtypes: float64(2), int64(8), object(4)
# memory usage: 9.2+ KB

# %%
df_store = pd.read_excel('https://github.com/insaid2018/Term-1/raw/master/Data/Casestudy/mcdonalds_store_data.xlsx')
df_store.head()
# Out:
#         Brand      Store ID     Store Name  \
# 0  McDonald's  23149-228271  Banjara Hills
# 1  McDonald's  23191-228548     Kukatpally
# 2  McDonald's  23193-228546       Madhapur
# 3  McDonald's  23180-228545  Jubilee Hills
# 4  McDonald's  24457-238129   Hi-Tech City
#
#                                       Street Address       City State  \
# 0  Lower Ground Floor, GVK One, Road Number 1, Ba...  Hyderabad    AP
# 1  Upper Ground Floor, Forum Sujana Mall, Kukatpally  Hyderabad    AP
# 2         Lower Ground Floor, Inorbit Mall, Madhapur  Hyderabad    AP
# 3  Ground Floor, Road No. 92, Near Apollo hospita...  Hyderabad    AP
# 4  Upper Ground Floor, Phoenix tower A, Opposite ...  Hyderabad    AP
#
#    Postcode  Longitude  Latitude       Revenue       Profits  Selling Price  \
# 0    500034      78.45     17.42  2.117344e+06  1.715839e+05   1.655165e+06
# 1    500072      78.39     17.48  1.058504e+06  5.464539e+04   8.959440e+05
# 2    500081      78.39     17.43  4.505020e+06  6.638673e+05   2.864311e+06
# 3    500033      78.42     17.42  3.405530e+06  3.978350e+05   2.394072e+06
# 4    500084      78.38     17.45  7.332713e+06  1.656524e+06   3.395053e+06
#
#      Cost Price  Gross Profit Margin  Number of Employees     Customers  \
# 0  9.074330e+05        747732.417746            34.311197   3979.583117
# 1  4.536446e+05        442299.411904            25.487533   1156.010620
# 2  1.930723e+06        933588.360542            54.208502  10346.720786
# 3  1.459513e+06        934559.026524            45.046083   7414.746544
# 4  3.142591e+06        252461.315787            77.772607  17887.234107
#
#         Most Prefered Meal     Most Selling Item
# 0        McAloo Tikki Meal          McEgg Burger
# 1  Chatpata Naan Aloo Meal  Chicken Maharaja Mac
# 2       Chicken Kebab Meal             McChicken
# 3            McVeggie Meal          Filet-O-Fish
# 4           McChicken Meal       Chicken McGrill

# %%
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 18 columns):
# Brand                  40 non-null object
# Store ID               40 non-null object
# Store Name             40 non-null object
# Street Address         40 non-null object
# City                   40 non-null object
# State                  40 non-null object
# Postcode               40 non-null int64
# Longitude              40 non-null float64
# Latitude               40 non-null float64
# Revenue                40 non-null float64
# Profits                40 non-null float64
# Selling Price          40 non-null float64
# Cost Price             40 non-null float64
# Gross Profit Margin    40 non-null float64
# Number of Employees    40 non-null float64
# Customers              40 non-null float64
#  Most Prefered Meal    40 non-null object
# Most Selling Item      40 non-null object
# dtypes: float64(9), int64(1), object(8)
# memory usage: 5.7+ KB

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline
import seaborn as sns
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)
import warnings
warnings.filterwarnings('ignore')

# %%
fig, ax = plt.subplots()

size = 0.3
vals = np.array([[60., 32.], [37., 40.], [29., 10.]])

cmap = plt.get_cmap("tab20c")
outer_colors = cmap(np.arange(3)*4)
inner_colors = cmap(np.array([1, 2, 5, 6, 9, 10]))

ax.pie(vals.sum(axis=1), radius=1, colors=outer_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.pie(vals.flatten(), radius=1-size, colors=inner_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title='Pie plot with `ax.pie`')
plt.show()
